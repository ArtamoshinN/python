# %%
import matplotlib.pyplot as plt
plt.title('qwerty')
plt.plot(4, 5, 1, 2)
plt.plot((2, 2.5), (3, 4))
plt.show()

# %%
from IPython import display
x = 2

# %% [markdown]
# $$_0^{\infty} f(x)dx$$

# %%
import math

def gaussian(x, mu, sigma):
    return math.exp(-0.5*((x-mu)/sigma)**2) / sigma / math.sqrt(2*math.pi)

# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from IPython.html.widgets import interact, interactive, fixed
import IPython.html.widgets as widgets

def interactiveGaussian(mu, sigma):
    xs = np.arange(-8, 8, 0.1)
    ys = [gaussian (x, mu, sigma) for x in xs]
    plt.plot(xs, ys)
    plt.ylim((0, 1))
    plt.show()

interact(interactiveGaussian, mu=(-10, 10), sigma=widgets.FloatSliderWidget(value=0.5, min=0.1, max=5))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['interactive']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/IPython/utils/importstring.py in import_item(name)
#      32         try:
# ---> 33             pak = getattr(module, obj)
#      34         except AttributeError:
#
# AttributeError: module 'ipywidgets' has no attribute 'FloatSliderWidget'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/IPython/utils/shimmodule.py in __getattr__(self, key)
#      91         try:
# ---> 92             return import_item(name)
#      93         except ImportError:
#
# /usr/local/lib/python3.6/site-packages/IPython/utils/importstring.py in import_item(name)
#      34         except AttributeError:
# ---> 35             raise ImportError('No module named %s' % obj)
#      36         return pak
#
# ImportError: No module named FloatSliderWidget
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-ad1378c4fa5e> in <module>()
#      17     plt.show()
#      18
# ---> 19 interact(interactiveGaussian, mu=(-10, 10), sigma=widgets.FloatSliderWidget(value=0.5, min=0.1, max=5))
#
# /usr/local/lib/python3.6/site-packages/IPython/utils/shimmodule.py in __getattr__(self, key)
#      92             return import_item(name)
#      93         except ImportError:
# ---> 94             raise AttributeError(key)
#
# AttributeError: FloatSliderWidget

# %%
import math

def gaussian(x, mu, sigma):
    return math.exp(-0.5*((x-mu)/sigma)**2) / sigma / math.sqrt(2*math.pi)

import numpy as np
import matplotlib.pyplot as plt

xs = np.arange(-8, 8, 0.05) # Сетка значений по оси абсцисс.
p1, = plt.plot(xs, [gaussian(x, 0, .5) for x in xs], label='$\sigma = 0.5$')
p2, = plt.plot(xs, [gaussian(x, 0, 1) for x in xs], label='$\sigma = 1$')
p3, = plt.plot(xs, [gaussian(x, 0, 2) for x in xs], label='$\sigma = 2$')
plt.legend()
plt.show()
